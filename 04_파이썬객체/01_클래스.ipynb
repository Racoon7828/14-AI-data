# %%
result = 0

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))
print(add(5))
# Out:
# 3
# 7
# 12

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add2(4))
print(add1(5))
print(add2(6))
# Out:
# 3
# 4
# 8
# 10

# %%
# 계산기
class Calculator:
    def __init__(self):
        self.result = 0
    
    def add(self, num):
        self.result += num
        return self.result
    
    def sub(self, num):
        self.result -= num
        return self.result
    
    def mul(self, num):
        self.result *= num
        return self.result
    
    def div(self, num):
        self.result /= num
        return self.result
    
    def reset(self):
        self.result = 0
        return self.result
    
cal1 = Calculator()
print(cal1.add(5))
print(cal1.add(10))
print(cal1.add(10))
print(cal1.reset(),'\n')

print(cal1.add(10))
print(cal1.sub(5))
print(cal1.mul(4))
print(cal1.div(2))
print(cal1.reset())
# Out:
# 5
# 15
# 25
# 0
#
# 10
# 5
# 20
# 10.0
# 0

# %%
class Calculator:
    def __init__(self):
        self.result = 0
    
    def add(self, num):
        self.result += num
        return self.result
    
    def sub(self, num):
        self.result -= num
        return self.result
    
    def mul(self, num):
        self.result *= num
        return self.result
    
    def div(self, num):
        self.result /= num
        return self.result
    
    def reset(self):
        self.result = 0
        return self.result
    
cal1 = Calculator()
print(cal1.add(10))
print(cal1.sub(2))
print(cal1.mul(5))
print(cal1.div(4),'\n')

cal2 = Calculator()
print(cal2.add(5))
print(cal2.sub(10))
print(cal2.mul(10))
print(cal2.div(5))
# Out:
# 10
# 8
# 40
# 10.0
#
# 5
# -5
# -50
# -10.0

# %%
# 객체에 연산할 숫자 지정하기
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second
    
    def add(self):
        result = self.first + self.second
        return result

cal3 = FourCal()
print(type(cal3))
cal3.setdata(4,2)
  
print(cal3.first)
print(cal3.second)
print(cal3.add())
# Out:
# <class '__main__.FourCal'>
# 4
# 2
# 6

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second
    
    def add(self):
        result = self.first + self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result
    
cal4 = FourCal()
cal4.setdata(10,5)

print(cal4.add())
print(cal4.sub())
print(cal4.mul())
print(cal4.div())
# Out:
# 15
# 5
# 50
# 2.0

# %%
# __init__ 메서드도 첫 번째 매개변수 self에 생성되는 객체가 자동으로 전달
# __init__ 메서드가 호출되면 setdata 메서드를 호출했을 때와 마찬가지로 first와 second라는 객체변수가 생성

class FourCal:
    def __init__(self, first, second):
        self.first = first
        self.second = second
    
    def add(self):
        result = self.first + self.second
        return result
    
cal5 = FourCal(10, 20)
print(cal5.first)
print(cal5.second)

print(cal5.add())
# Out:
# 10
# 20
# 30

# %%
# 클래스의 상속
#  어떤 클래스를 만들 때 다른 클래스의 기능을 물려받을 수 있게 만드는 것이다.
class MorefourCal(FourCal):
    pass

# %%
cal6 = MorefourCal(4,2)
print(cal6.add())
# Out:
# 6

# %%
class MorefourCal(FourCal):
    def pow(self):
        result = self.first ** self.second
        return result

# %%
cal7 = MorefourCal(10,2)
print(cal7.add())
print(cal7.pow())
# Out:
# 12
# 100

# %%
# 메서드 오버라이딩
# 메서드를 오버라이딩하면 부모 클래스의 메서드 대신 오버라이딩한 메서드가 호출된다.
class MorefourCal(FourCal):
    def add(self):
        result = self.first * self.second
        return result

# %%
cal7 = MorefourCal(5,6)
print(cal7.add())
# Out:
# 30
