# %%
# Do not reinvert the wheel
from faker import Faker

fake = Faker()
fake.name()
# Out:
# 'Jason Leonard'

# %%
fake.address()
# Out:
# '1867 Sean Camp\nLake Iantown, WI 05902'

# %%
test_data = [(fake.name(), fake.address()) for i in range(30)]
print(test_data)
# Out:
# [('Sandra Carter', '4365 Pamela Course Suite 573\nJamestown, MS 50113'), ('Alyssa Jackson', '929 Avila Island\nLake Susan, NH 89272'), ('Nicholas Nelson', '552 Samantha Trafficway Suite 312\nAmyport, IN 22035'), ('John Berg', '01976 Stokes Villages\nSouth Peterview, SD 45205'), ('Cathy Hodge', '012 Jenkins Route Apt. 896\nEast Meganchester, DE 31335'), ('Leslie Sullivan', 'Unit 0791 Box 5605\nDPO AE 36186'), ('Julie Bowman', '20844 Moody River Suite 034\nPort Rebecca, NV 34062'), ('Mr. Russell Grant', '55522 Andrade Lakes Suite 216\nWest Elizabeth, ID 76758'), ('Rachael Jenkins', '27429 Pollard Neck\nMontesview, MS 98818'), ('Mark Turner', 'USS Patterson\nFPO AE 45963'), ('Amy Wolfe', '453 Moran Trail Apt. 079\nWarnerhaven, WI 91371'), ('Allison Rodriguez', '51254 David Avenue Suite 635\nWest Kevinmouth, OR 66701'), ('Joshua Roberts', '32846 Chad Road Apt. 896\nGarymouth, AL 58348'), ('Charles Rios', '34479 Danielle Coves\nHarryburgh, AK 23448'), ('Samuel Allen', '277 Newton View Apt
# ...
